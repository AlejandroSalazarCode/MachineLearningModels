# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
import pandas as pd
housing = pd.read_csv('/content/sample_data/california_housing_train.csv')
display(housing.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
print(housing.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
#Separate features and target
X = housing.drop("median_house_value", axis=1)
y = housing["median_house_value"].copy()

# %%
#numerical and categorical data
num_attribs = list(X.columns) # All remaining columns are numerical
cat_attribs = [] # No categorical attributes in this dataset

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")), # Fill missing bedrooms with median
])

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attribs),
], remainder='passthrough') # Handle potential other columns if any, though not expected here

# %%
#unified pipeline with desicion tree
tree_reg = Pipeline([
    ("preprocessing", full_pipeline),
    ("tree_model", DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, random_state=42))
])

tree_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_bedrooms',
#                                                    'population', 'households',
#                                                    'median_income'])])),
#                 ('tree_model',
#                  DecisionTreeRegressor(max_depth=10, min_samples_leaf=5,
#                                        random_state=42))])

# %%
#Evaluation
predictions = tree_reg.predict(X_train)
tree_mse = mean_squared_error(y_train, predictions)
tree_rmse = np.sqrt(tree_mse)

print(f"Decision Tree RMSE on Training Set: ${tree_rmse:.2f}")
# Out:
# Decision Tree RMSE on Training Set: $47531.63
